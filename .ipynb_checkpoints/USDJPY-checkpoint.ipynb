# %% [markdown]
# # USD vs. GBP

# %% [markdown]
# ### Part I : Peeling out the monetary shock

# %%
Docker = "To peel out a monetary shocks TS, the data needed are:\n \
          * The federal funds rate series \n \
          * The inflation sequence \n \
          * The output gap sequence."
"""To get the output gap sequence, we use a quadratic function to fit the trend and determine the gap."""
import pandas as pd
import numpy as np
from datetime import datetime
import datetime as dt
from matplotlib import pyplot as plt
# %matplotlib inline
import statsmodels.api as sm
import seaborn as sns
sns.set()

def flashBack(old,n,mode="month"):
    #Get the back the argued period of time
    if mode == "month":
        #Flash back by month
        year = old.year - int((n - n%12)/12)
        res = n%12
        if res >= old.month:
            #We have to go back an extra year
            year = year - 1
            month = 12 + old.month - res
        else:
            month = old.month - res
        result = datetime(year,month,old.day)
    return result

def grabForward(target,domain):
    #Get the closest datetime to the target dt, in the domain time series indexed by the datetimess.
    tmp = domain[target:]
    try:
        return tmp.iloc[0,:].values
    except:
        return tmp.iloc[0]

def grabNearest(target,domain,output=False):
    #Get the colest datetime to the target dt.
    #Domain has to a datetime indexed Series or DataFrame.
    left = domain[:target]
    right = domain[target:]
    if len(left) == 0:
        tt = right.index[0]
    elif len(right) == 0:
        tt = left.index[-1]
    else:
        candidate = [right.index[0],left.index[-1]]
        dev = [abs(x-target) for x in candidate]
        if dev[0] <= dev[1]:
            tt = candidate[0]
        else:
            tt = candidate[1]
    if output == True:
        print("@Function [grabNearest] grabbed tt at %s"%tt)
    if isinstance(domain,pd.Series):
        return domain[tt]
    elif isinstance(domain,pd.DataFrame):
        return domain[tt].values
    else:
        raise ValueError

# %%
#Configuration
start = datetime(1994,1,1)
end = datetime(2008,1,1)
regressStart = datetime(1990,1,1)
regressEnd = datetime(2008,1,1)
latex = False
pin_date = 15      #The standing date for month frequecy data entry.

# %% [markdown]
# #### Get the output gap time series

# %%
#Data inquiry
otpt_raw = pd.read_excel("data/production.xlsx")
otpt = pd.Series(otpt_raw.iloc[:,1].values,index=otpt_raw.iloc[:,0].values,name="industrial_output")[start:end]

# %%
#Fitting the quadratic model
regress = pd.DataFrame({'output':otpt})
regress['time'] = np.arange(len(regress))
regress['timesq'] = regress['time']**2
regress['constant'] = 1
model = sm.OLS(regress['output'],regress.drop('output',axis=1))
gapResult = model.fit(cov_type="HC3")
#Get the residual series
output_gap = gapResult.resid
output_gap.index = pd.to_datetime(output_gap.index)
output_gap.name = "outputgap"

# %%
output_gap.plot(figsize=(10,5),grid=True)

# %%
#Set the common time line
timeline = output_gap.index

# %% [markdown]
# #### Get the inflation time series

# %%
#Data inquiry
infl_raw = pd.read_excel("data/inflation.xlsx",skiprows=3)
cpi = pd.Series(infl_raw.iloc[:,1].values,index=infl_raw.iloc[:,0].values,name="cpi")[flashBack(start,1):end]
infl = cpi.pct_change().dropna()

# %% [markdown]
# #### Get the federal funds rate

# %%
#Data inquiry
iff_raw = pd.read_excel("data/FEDFUNDS.xls",skiprows=10)
iff_tmp = pd.Series(iff_raw['FEDFUNDS'].values,index=iff_raw['observation_date'].values,name = "iff")

# %%
#Shaping the series, awkward.
iff1 = pd.Series(np.nan,index=timeline)
for time in timeline:
    iff1[time] = grabForward(target=time,domain=iff_tmp)
head = flashBack(timeline[0],1)
iff1[head] = grabForward(head,iff_tmp)
iff1 = iff1.sort_index()
iff = iff1[iff1.index[1:]]
iff_lag = iff1.shift().dropna()
iff.name = "iffrate"
iff_lag.name = "iffratelag"

# %% [markdown]
# #### Run the Taylor's model.

# %%
regress = pd.DataFrame([iff,output_gap,infl,iff_lag]).T
regress['Constant'] = 1
taylorModel = sm.OLS(regress.iffrate,regress.drop('iffrate',axis=1))
taylorResult = taylorModel.fit(cov_type="HC3")

# %%
estimation = regress.drop("iffrate",axis=1).values.dot(taylorResult.params.values)

# %%
compare = pd.DataFrame({"estimated":estimation,"original":iff},index=timeline)
compare.plot()

# %% [markdown]
# #### Peel out the monetary shock of US

# %%
monetaryShock = taylorResult.resid
monetaryShock.name = "monetaryShock"
monetaryShock.plot(figsize=(10,5),grid=True)

# %% [markdown]
# ### Part II : Get the UIP deviation estimation

# %%
"""The way to estimate the deviation from UIP equation is to use a forward difference of spot exchange rate"""
# Out:
# 'The way to estimate the deviation from UIP equation is to use a forward difference of spot exchange rate'

# %%
#Data inquiry
exch_raw = pd.read_excel("data/exchange_rate.xlsx")
exch = np.log(pd.Series(1/exch_raw["JAPANESE YEN TO US $ (WMR) - EXCHANGE RATE"].values,index=exch_raw['Name'].values,name="CADollarPrice"))
interest_raw = pd.read_excel("data/interest_rate.xlsx")
iUS = pd.Series(interest_raw["TR US GVT BMK BID YLD 1Y (U$) - RED. YIELD"].values,index=interest_raw.iloc[:,0].values,name="iUS")
iJP = pd.Series(interest_raw["JAPANESE YEN 1Y DEPOSIT (FT/TR) - MIDDLE RATE"].values,index=interest_raw.iloc[:,0].values,name="iCA")

# %%
exch.dropna().plot()

# %%
#Shaping the LHS,RHS,p_t series
pt = pd.Series(np.nan,index=timeline)
sdif = pd.Series(np.nan,index=timeline)
idif = pd.Series(np.nan,index=timeline)

for time in timeline:
    print(time)
    sdif[time] = grabNearest(target=datetime(time.year+1,time.month,time.day),domain=exch) - grabNearest(time,exch)
    idif[time] = grabNearest(time,iUS,True) - grabNearest(time,iJP,True)

pt = sdif-idif
# Out:
# 1994-01-15 00:00:00
# @Function [grabNearest] grabbed tt at 1994-01-14 00:00:00
# @Function [grabNearest] grabbed tt at 1994-01-14 00:00:00
# 1994-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 1994-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 1994-02-15 00:00:00
# 1994-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 1994-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 1994-03-15 00:00:00
# 1994-04-15 00:00:00
# @Function [grabNearest] grabbed tt at 1994-04-15 00:00:00
# @Function [grabNearest] grabbed tt at 1994-04-15 00:00:00
# 1994-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 1994-05-16 00:00:00
# @Function [grabNearest] grabbed tt at 1994-05-16 00:00:00
# 1994-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 1994-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 1994-06-15 00:00:00
# 1994-07-15 00:00:00
# @Function [grabNearest] grabbed tt at 1994-07-15 00:00:00
# @Function [grabNearest] grabbed tt at 1994-07-15 00:00:00
# 1994-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 1994-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 1994-08-15 00:00:00
# 1994-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 1994-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 1994-09-15 00:00:00
# 1994-10-15 00:00:00
# @Function [grabNearest] grabbed tt at 1994-10-14 00:00:00
# @Function [grabNearest] grabbed tt at 1994-10-14 00:00:00
# 1994-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 1994-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 1994-11-15 00:00:00
# 1994-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 1994-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 1994-12-15 00:00:00
# 1995-01-15 00:00:00
# @Function [grabNearest] grabbed tt at 1995-01-16 00:00:00
# @Function [grabNearest] grabbed tt at 1995-01-16 00:00:00
# 1995-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 1995-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 1995-02-15 00:00:00
# 1995-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 1995-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 1995-03-15 00:00:00
# 1995-04-15 00:00:00
# @Function [grabNearest] grabbed tt at 1995-04-14 00:00:00
# @Function [grabNearest] grabbed tt at 1995-04-14 00:00:00
# 1995-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 1995-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 1995-05-15 00:00:00
# 1995-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 1995-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 1995-06-15 00:00:00
# 1995-07-15 00:00:00
# @Function [grabNearest] grabbed tt at 1995-07-14 00:00:00
# @Function [grabNearest] grabbed tt at 1995-07-14 00:00:00
# 1995-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 1995-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 1995-08-15 00:00:00
# 1995-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 1995-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 1995-09-15 00:00:00
# 1995-10-15 00:00:00
# @Function [grabNearest] grabbed tt at 1995-10-16 00:00:00
# @Function [grabNearest] grabbed tt at 1995-10-16 00:00:00
# 1995-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 1995-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 1995-11-15 00:00:00
# 1995-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 1995-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 1995-12-15 00:00:00
# 1996-01-15 00:00:00
# @Function [grabNearest] grabbed tt at 1996-01-15 00:00:00
# @Function [grabNearest] grabbed tt at 1996-01-15 00:00:00
# 1996-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 1996-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 1996-02-15 00:00:00
# 1996-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 1996-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 1996-03-15 00:00:00
# 1996-04-15 00:00:00
# @Function [grabNearest] grabbed tt at 1996-04-15 00:00:00
# @Function [grabNearest] grabbed tt at 1996-04-15 00:00:00
# 1996-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 1996-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 1996-05-15 00:00:00
# 1996-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 1996-06-14 00:00:00
# @Function [grabNearest] grabbed tt at 1996-06-14 00:00:00
# 1996-07-15 00:00:00
# @Function [grabNearest] grabbed tt at 1996-07-15 00:00:00
# @Function [grabNearest] grabbed tt at 1996-07-15 00:00:00
# 1996-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 1996-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 1996-08-15 00:00:00
# 1996-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 1996-09-16 00:00:00
# @Function [grabNearest] grabbed tt at 1996-09-16 00:00:00
# 1996-10-15 00:00:00
# @Function [grabNearest] grabbed tt at 1996-10-15 00:00:00
# @Function [grabNearest] grabbed tt at 1996-10-15 00:00:00
# 1996-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 1996-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 1996-11-15 00:00:00
# 1996-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 1996-12-16 00:00:00
# @Function [grabNearest] grabbed tt at 1996-12-16 00:00:00
# 1997-01-15 00:00:00
# @Function [grabNearest] grabbed tt at 1997-01-15 00:00:00
# @Function [grabNearest] grabbed tt at 1997-01-15 00:00:00
# 1997-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 1997-02-14 00:00:00
# @Function [grabNearest] grabbed tt at 1997-02-14 00:00:00
# 1997-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 1997-03-14 00:00:00
# @Function [grabNearest] grabbed tt at 1997-03-14 00:00:00
# 1997-04-15 00:00:00
# @Function [grabNearest] grabbed tt at 1997-04-15 00:00:00
# @Function [grabNearest] grabbed tt at 1997-04-15 00:00:00
# 1997-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 1997-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 1997-05-15 00:00:00
# 1997-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 1997-06-16 00:00:00
# @Function [grabNearest] grabbed tt at 1997-06-16 00:00:00
# 1997-07-15 00:00:00
# @Function [grabNearest] grabbed tt at 1997-07-15 00:00:00
# @Function [grabNearest] grabbed tt at 1997-07-15 00:00:00
# 1997-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 1997-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 1997-08-15 00:00:00
# 1997-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 1997-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 1997-09-15 00:00:00
# 1997-10-15 00:00:00
# @Function [grabNearest] grabbed tt at 1997-10-15 00:00:00
# @Function [grabNearest] grabbed tt at 1997-10-15 00:00:00
# 1997-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 1997-11-14 00:00:00
# @Function [grabNearest] grabbed tt at 1997-11-14 00:00:00
# 1997-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 1997-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 1997-12-15 00:00:00
# 1998-01-15 00:00:00
# @Function [grabNearest] grabbed tt at 1998-01-15 00:00:00
# @Function [grabNearest] grabbed tt at 1998-01-15 00:00:00
# 1998-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 1998-02-16 00:00:00
# @Function [grabNearest] grabbed tt at 1998-02-16 00:00:00
# 1998-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 1998-03-16 00:00:00
# @Function [grabNearest] grabbed tt at 1998-03-16 00:00:00
# 1998-04-15 00:00:00
# @Function [grabNearest] grabbed tt at 1998-04-15 00:00:00
# @Function [grabNearest] grabbed tt at 1998-04-15 00:00:00
# 1998-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 1998-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 1998-05-15 00:00:00
# 1998-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 1998-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 1998-06-15 00:00:00
# 1998-07-15 00:00:00
# @Function [grabNearest] grabbed tt at 1998-07-15 00:00:00
# @Function [grabNearest] grabbed tt at 1998-07-15 00:00:00
# 1998-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 1998-08-14 00:00:00
# @Function [grabNearest] grabbed tt at 1998-08-14 00:00:00
# 1998-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 1998-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 1998-09-15 00:00:00
# 1998-10-15 00:00:00
# @Function [grabNearest] grabbed tt at 1998-10-15 00:00:00
# @Function [grabNearest] grabbed tt at 1998-10-15 00:00:00
# 1998-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 1998-11-16 00:00:00
# @Function [grabNearest] grabbed tt at 1998-11-16 00:00:00
# 1998-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 1998-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 1998-12-15 00:00:00
# 1999-01-15 00:00:00
# @Function [grabNearest] grabbed tt at 1999-01-15 00:00:00
# @Function [grabNearest] grabbed tt at 1999-01-15 00:00:00
# 1999-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 1999-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 1999-02-15 00:00:00
# 1999-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 1999-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 1999-03-15 00:00:00
# 1999-04-15 00:00:00
# @Function [grabNearest] grabbed tt at 1999-04-15 00:00:00
# @Function [grabNearest] grabbed tt at 1999-04-15 00:00:00
# 1999-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 1999-05-14 00:00:00
# @Function [grabNearest] grabbed tt at 1999-05-14 00:00:00
# 1999-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 1999-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 1999-06-15 00:00:00
# 1999-07-15 00:00:00
# @Function [grabNearest] grabbed tt at 1999-07-15 00:00:00
# @Function [grabNearest] grabbed tt at 1999-07-15 00:00:00
# 1999-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 1999-08-16 00:00:00
# @Function [grabNearest] grabbed tt at 1999-08-16 00:00:00
# 1999-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 1999-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 1999-09-15 00:00:00
# 1999-10-15 00:00:00
# @Function [grabNearest] grabbed tt at 1999-10-15 00:00:00
# @Function [grabNearest] grabbed tt at 1999-10-15 00:00:00
# 1999-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 1999-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 1999-11-15 00:00:00
# 1999-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 1999-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 1999-12-15 00:00:00
# 2000-01-15 00:00:00
# @Function [grabNearest] grabbed tt at 2000-01-14 00:00:00
# @Function [grabNearest] grabbed tt at 2000-01-14 00:00:00
# 2000-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 2000-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 2000-02-15 00:00:00
# 2000-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 2000-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 2000-03-15 00:00:00
# 2000-04-15 00:00:00
# @Function [grabNearest] grabbed tt at 2000-04-14 00:00:00
# @Function [grabNearest] grabbed tt at 2000-04-14 00:00:00
# 2000-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 2000-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 2000-05-15 00:00:00
# 2000-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 2000-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 2000-06-15 00:00:00
# 2000-07-15 00:00:00
# @Function [grabNearest] grabbed tt at 2000-07-14 00:00:00
# @Function [grabNearest] grabbed tt at 2000-07-14 00:00:00
# 2000-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 2000-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 2000-08-15 00:00:00
# 2000-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 2000-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 2000-09-15 00:00:00
# 2000-10-15 00:00:00
# @Function [grabNearest] grabbed tt at 2000-10-16 00:00:00
# @Function [grabNearest] grabbed tt at 2000-10-16 00:00:00
# 2000-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 2000-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 2000-11-15 00:00:00
# 2000-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 2000-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 2000-12-15 00:00:00
# 2001-01-15 00:00:00
# @Function [grabNearest] grabbed tt at 2001-01-15 00:00:00
# @Function [grabNearest] grabbed tt at 2001-01-15 00:00:00
# 2001-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 2001-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 2001-02-15 00:00:00
# 2001-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 2001-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 2001-03-15 00:00:00
# 2001-04-15 00:00:00
# @Function [grabNearest] grabbed tt at 2001-04-16 00:00:00
# @Function [grabNearest] grabbed tt at 2001-04-16 00:00:00
# 2001-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 2001-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 2001-05-15 00:00:00
# 2001-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 2001-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 2001-06-15 00:00:00
# 2001-07-15 00:00:00
# @Function [grabNearest] grabbed tt at 2001-07-16 00:00:00
# @Function [grabNearest] grabbed tt at 2001-07-16 00:00:00
# 2001-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 2001-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 2001-08-15 00:00:00
# 2001-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 2001-09-14 00:00:00
# @Function [grabNearest] grabbed tt at 2001-09-14 00:00:00
# 2001-10-15 00:00:00
# @Function [grabNearest] grabbed tt at 2001-10-15 00:00:00
# @Function [grabNearest] grabbed tt at 2001-10-15 00:00:00
# 2001-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 2001-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 2001-11-15 00:00:00
# 2001-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 2001-12-14 00:00:00
# @Function [grabNearest] grabbed tt at 2001-12-14 00:00:00
# 2002-01-15 00:00:00
# @Function [grabNearest] grabbed tt at 2002-01-15 00:00:00
# @Function [grabNearest] grabbed tt at 2002-01-15 00:00:00
# 2002-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 2002-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 2002-02-15 00:00:00
# 2002-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 2002-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 2002-03-15 00:00:00
# 2002-04-15 00:00:00
# @Function [grabNearest] grabbed tt at 2002-04-15 00:00:00
# @Function [grabNearest] grabbed tt at 2002-04-15 00:00:00
# 2002-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 2002-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 2002-05-15 00:00:00
# 2002-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 2002-06-14 00:00:00
# @Function [grabNearest] grabbed tt at 2002-06-14 00:00:00
# 2002-07-15 00:00:00
# @Function [grabNearest] grabbed tt at 2002-07-15 00:00:00
# @Function [grabNearest] grabbed tt at 2002-07-15 00:00:00
# 2002-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 2002-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 2002-08-15 00:00:00
# 2002-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 2002-09-16 00:00:00
# @Function [grabNearest] grabbed tt at 2002-09-16 00:00:00
# 2002-10-15 00:00:00
# @Function [grabNearest] grabbed tt at 2002-10-15 00:00:00
# @Function [grabNearest] grabbed tt at 2002-10-15 00:00:00
# 2002-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 2002-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 2002-11-15 00:00:00
# 2002-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 2002-12-16 00:00:00
# @Function [grabNearest] grabbed tt at 2002-12-16 00:00:00
# 2003-01-15 00:00:00
# @Function [grabNearest] grabbed tt at 2003-01-15 00:00:00
# @Function [grabNearest] grabbed tt at 2003-01-15 00:00:00
# 2003-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 2003-02-14 00:00:00
# @Function [grabNearest] grabbed tt at 2003-02-14 00:00:00
# 2003-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 2003-03-14 00:00:00
# @Function [grabNearest] grabbed tt at 2003-03-14 00:00:00
# 2003-04-15 00:00:00
# @Function [grabNearest] grabbed tt at 2003-04-15 00:00:00
# @Function [grabNearest] grabbed tt at 2003-04-15 00:00:00
# 2003-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 2003-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 2003-05-15 00:00:00
# 2003-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 2003-06-16 00:00:00
# @Function [grabNearest] grabbed tt at 2003-06-16 00:00:00
# 2003-07-15 00:00:00
# @Function [grabNearest] grabbed tt at 2003-07-15 00:00:00
# @Function [grabNearest] grabbed tt at 2003-07-15 00:00:00
# 2003-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 2003-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 2003-08-15 00:00:00
# 2003-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 2003-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 2003-09-15 00:00:00
# 2003-10-15 00:00:00
# @Function [grabNearest] grabbed tt at 2003-10-15 00:00:00
# @Function [grabNearest] grabbed tt at 2003-10-15 00:00:00
# 2003-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 2003-11-14 00:00:00
# @Function [grabNearest] grabbed tt at 2003-11-14 00:00:00
# 2003-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 2003-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 2003-12-15 00:00:00
# 2004-01-15 00:00:00
# @Function [grabNearest] grabbed tt at 2004-01-15 00:00:00
# @Function [grabNearest] grabbed tt at 2004-01-15 00:00:00
# 2004-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 2004-02-16 00:00:00
# @Function [grabNearest] grabbed tt at 2004-02-16 00:00:00
# 2004-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 2004-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 2004-03-15 00:00:00
# 2004-04-15 00:00:00
# @Function [grabNearest] grabbed tt at 2004-04-15 00:00:00
# @Function [grabNearest] grabbed tt at 2004-04-15 00:00:00
# 2004-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 2004-05-14 00:00:00
# @Function [grabNearest] grabbed tt at 2004-05-14 00:00:00
# 2004-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 2004-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 2004-06-15 00:00:00
# 2004-07-15 00:00:00
# @Function [grabNearest] grabbed tt at 2004-07-15 00:00:00
# @Function [grabNearest] grabbed tt at 2004-07-15 00:00:00
# 2004-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 2004-08-16 00:00:00
# @Function [grabNearest] grabbed tt at 2004-08-16 00:00:00
# 2004-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 2004-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 2004-09-15 00:00:00
# 2004-10-15 00:00:00
# @Function [grabNearest] grabbed tt at 2004-10-15 00:00:00
# @Function [grabNearest] grabbed tt at 2004-10-15 00:00:00
# 2004-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 2004-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 2004-11-15 00:00:00
# 2004-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 2004-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 2004-12-15 00:00:00
# 2005-01-15 00:00:00
# @Function [grabNearest] grabbed tt at 2005-01-14 00:00:00
# @Function [grabNearest] grabbed tt at 2005-01-14 00:00:00
# 2005-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 2005-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 2005-02-15 00:00:00
# 2005-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 2005-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 2005-03-15 00:00:00
# 2005-04-15 00:00:00
# @Function [grabNearest] grabbed tt at 2005-04-15 00:00:00
# @Function [grabNearest] grabbed tt at 2005-04-15 00:00:00
# 2005-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 2005-05-16 00:00:00
# @Function [grabNearest] grabbed tt at 2005-05-16 00:00:00
# 2005-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 2005-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 2005-06-15 00:00:00
# 2005-07-15 00:00:00
# @Function [grabNearest] grabbed tt at 2005-07-15 00:00:00
# @Function [grabNearest] grabbed tt at 2005-07-15 00:00:00
# 2005-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 2005-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 2005-08-15 00:00:00
# 2005-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 2005-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 2005-09-15 00:00:00
# 2005-10-15 00:00:00
# @Function [grabNearest] grabbed tt at 2005-10-14 00:00:00
# @Function [grabNearest] grabbed tt at 2005-10-14 00:00:00
# 2005-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 2005-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 2005-11-15 00:00:00
# 2005-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 2005-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 2005-12-15 00:00:00
# 2006-01-15 00:00:00
# @Function [grabNearest] grabbed tt at 2006-01-16 00:00:00
# @Function [grabNearest] grabbed tt at 2006-01-16 00:00:00
# 2006-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 2006-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 2006-02-15 00:00:00
# 2006-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 2006-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 2006-03-15 00:00:00
# 2006-04-15 00:00:00
# @Function [grabNearest] grabbed tt at 2006-04-14 00:00:00
# @Function [grabNearest] grabbed tt at 2006-04-14 00:00:00
# 2006-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 2006-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 2006-05-15 00:00:00
# 2006-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 2006-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 2006-06-15 00:00:00
# 2006-07-15 00:00:00
# @Function [grabNearest] grabbed tt at 2006-07-14 00:00:00
# @Function [grabNearest] grabbed tt at 2006-07-14 00:00:00
# 2006-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 2006-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 2006-08-15 00:00:00
# 2006-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 2006-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 2006-09-15 00:00:00
# 2006-10-15 00:00:00
# @Function [grabNearest] grabbed tt at 2006-10-16 00:00:00
# @Function [grabNearest] grabbed tt at 2006-10-16 00:00:00
# 2006-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 2006-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 2006-11-15 00:00:00
# 2006-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 2006-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 2006-12-15 00:00:00
# 2007-01-15 00:00:00
# @Function [grabNearest] grabbed tt at 2007-01-15 00:00:00
# @Function [grabNearest] grabbed tt at 2007-01-15 00:00:00
# 2007-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 2007-02-15 00:00:00
# @Function [grabNearest] grabbed tt at 2007-02-15 00:00:00
# 2007-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 2007-03-15 00:00:00
# @Function [grabNearest] grabbed tt at 2007-03-15 00:00:00
# 2007-04-15 00:00:00
# @Function [grabNearest] grabbed tt at 2007-04-16 00:00:00
# @Function [grabNearest] grabbed tt at 2007-04-16 00:00:00
# 2007-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 2007-05-15 00:00:00
# @Function [grabNearest] grabbed tt at 2007-05-15 00:00:00
# 2007-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 2007-06-15 00:00:00
# @Function [grabNearest] grabbed tt at 2007-06-15 00:00:00
# 2007-07-15 00:00:00
# @Function [grabNearest] grabbed tt at 2007-07-16 00:00:00
# @Function [grabNearest] grabbed tt at 2007-07-16 00:00:00
# 2007-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 2007-08-15 00:00:00
# @Function [grabNearest] grabbed tt at 2007-08-15 00:00:00
# 2007-09-15 00:00:00
# @Function [grabNearest] grabbed tt at 2007-09-14 00:00:00
# @Function [grabNearest] grabbed tt at 2007-09-14 00:00:00
# 2007-10-15 00:00:00
# @Function [grabNearest] grabbed tt at 2007-10-15 00:00:00
# @Function [grabNearest] grabbed tt at 2007-10-15 00:00:00
# 2007-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 2007-11-15 00:00:00
# @Function [grabNearest] grabbed tt at 2007-11-15 00:00:00
# 2007-12-15 00:00:00
# @Function [grabNearest] grabbed tt at 2007-12-14 00:00:00
# @Function [grabNearest] grabbed tt at 2007-12-14 00:00:00

# %%
#Regress pt on monetaryShock
if not (pt.index == monetaryShock.index).all(): #Check the index
    raise ValueError
dataset = pd.DataFrame({"UIPdev":pt,"Constant":1,"monetaryShock":monetaryShock}).dropna()
model1 = sm.OLS(dataset["UIPdev"],dataset[["Constant","monetaryShock"]])
result1 = model1.fit(cov_type="HAC",cov_kwds={"maxlags":1})
if latex == True:
    for line in result1.summary().tables:
        print(line.as_latex_tabular())
print(result1.summary())
plt.scatter(monetaryShock.values,pt.values)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 UIPdev   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     1.644
# Date:                Wed, 05 Dec 2018   Prob (F-statistic):              0.202
# Time:                        16:09:21   Log-Likelihood:                -299.33
# No. Observations:                 168   AIC:                             602.7
# Df Residuals:                     166   BIC:                             608.9
# Df Model:                           1
# Covariance Type:                  HAC
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Constant         -3.7448      0.156    -24.077      0.000      -4.050      -3.440
# monetaryShock    -0.8184      0.638     -1.282      0.200      -2.069       0.433
# ==============================================================================
# Omnibus:                       37.662   Durbin-Watson:                   0.042
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               13.871
# Skew:                           0.480   Prob(JB):                     0.000972
# Kurtosis:                       1.970   Cond. No.                         5.60
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction

# %%
#Adding a exchange rate lag term
exch_lag = exch - exch.shift(3)
intervn = pd.Series([grabNearest(x,exch_lag) for x in timeline],index=timeline,name="intervention")
dataset["intervention"] = intervn
dataset = dataset.dropna()
model2 = sm.OLS(dataset["UIPdev"],dataset[["Constant","monetaryShock","intervention"]])
result2 = model2.fit(cov_type="HAC",cov_kwds={"maxlags":1})
if latex == True:
    for line in result2.summary().tables:
        print(line.as_latex_tabular())
print(result2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 UIPdev   R-squared:                       0.056
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     3.973
# Date:                Wed, 05 Dec 2018   Prob (F-statistic):             0.0207
# Time:                        16:09:21   Log-Likelihood:                -288.43
# No. Observations:                 165   AIC:                             582.9
# Df Residuals:                     162   BIC:                             592.2
# Df Model:                           2
# Covariance Type:                  HAC
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Constant         -3.7815      0.152    -24.958      0.000      -4.078      -3.485
# monetaryShock    -1.0404      0.594     -1.750      0.080      -2.205       0.125
# intervention      4.8636      2.198      2.213      0.027       0.556       9.171
# ==============================================================================
# Omnibus:                       22.030   Durbin-Watson:                   0.077
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               11.544
# Skew:                           0.474   Prob(JB):                      0.00311
# Kurtosis:                       2.117   Cond. No.                         16.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction

# %%
modelInterv = sm.OLS(dataset["UIPdev"],dataset[["Constant","intervention"]])
resultInterv = modelInterv.fit(cov_type="HAC",cov_kwds={"maxlags":1})
if latex == True:
    for line in resultInterv.summary().tables:
        print(line.as_latex_tabular())
print(resultInterv.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 UIPdev   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     4.961
# Date:                Wed, 05 Dec 2018   Prob (F-statistic):             0.0273
# Time:                        16:09:21   Log-Likelihood:                -289.89
# No. Observations:                 165   AIC:                             583.8
# Df Residuals:                     163   BIC:                             590.0
# Df Model:                           1
# Covariance Type:                  HAC
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Constant        -3.7785      0.153    -24.669      0.000      -4.079      -3.478
# intervention     4.8216      2.165      2.227      0.026       0.579       9.064
# ==============================================================================
# Omnibus:                       17.883   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               10.747
# Skew:                           0.474   Prob(JB):                      0.00464
# Kurtosis:                       2.184   Cond. No.                         16.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction

# %%
dataset["exchgrt"] = pd.Series([grabNearest(x,exch) for x in dataset.index],index=dataset.index,name="exchgrt")
dataset.to_stata("dataset.dta")

# %% [markdown]
# # Control the terms in UIP regression.

# %%
dataset["sdif"] = sdif
dataset["idif"] = idif

# %%
#Dataset1 is a lagged shock and intervention version of original dataset
dataset1 = dataset.copy()

lag_shock,lag_intervention = 6,1
dataset1["monetaryShock"] = dataset1["monetaryShock"].shift(lag_shock)
dataset1["intervention"] = dataset1["intervention"].shift(lag_intervention)
dataset1 = dataset1.dropna()
model3 = sm.OLS(dataset1["sdif"],dataset1[["Constant","monetaryShock","intervention","idif"]])
result3 = model3.fit(cov_type="HAC",cov_kwds={"maxlags":1})
"""
for lag1 in range(1,10):
    for lag2 in range(1,10):
        dataset1 = dataset.copy()
        dataset1["monetaryShock"] = dataset1["monetaryShock"].shift(lag1)
        dataset1["intervention"] = dataset1["intervention"].shift(lag2)
        dataset1 = dataset1.dropna()
        model3 = sm.OLS(dataset1["sdif"],dataset1[["Constant","monetaryShock","intervention","idif"]])
        result3 = model3.fit(cov_type="HAC",cov_kwds={"maxlags":1})
        print("[lag1:%s,lag2:%s] coef of RHS is %s" %(lag1,lag2,result3.pvalues["monetaryShock"]))
result3.bse
"""
print(result3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   sdif   R-squared:                       0.216
# Model:                            OLS   Adj. R-squared:                  0.201
# Method:                 Least Squares   F-statistic:                     14.98
# Date:                Wed, 05 Dec 2018   Prob (F-statistic):           1.30e-08
# Time:                        16:09:21   Log-Likelihood:                 151.61
# No. Observations:                 159   AIC:                            -295.2
# Df Residuals:                     155   BIC:                            -283.0
# Df Model:                           3
# Covariance Type:                  HAC
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Constant          0.0793      0.019      4.128      0.000       0.042       0.117
# monetaryShock    -0.1618      0.047     -3.416      0.001      -0.255      -0.069
# intervention     -0.1367      0.205     -0.667      0.505      -0.539       0.265
# idif             -0.0226      0.006     -3.954      0.000      -0.034      -0.011
# ==============================================================================
# Omnibus:                        4.925   Durbin-Watson:                   0.320
# Prob(Omnibus):                  0.085   Jarque-Bera (JB):                4.873
# Skew:                           0.388   Prob(JB):                       0.0875
# Kurtosis:                       2.636   Cond. No.                         73.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction

# %%
if latex == True:
    for line in result3.summary().tables:
        print(line.as_latex_tabular())

# %%
UIPmodel = sm.OLS(dataset["sdif"],dataset[["Constant","idif"]])
UIPresult = UIPmodel.fit(cov_type="HAC",cov_kwds={"maxlags":1})
if latex == True:
    for line in UIPresult.summary().tables:
        print(line.as_latex_tabular())
UIPresult.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   sdif   R-squared:                       0.153
# Model:                            OLS   Adj. R-squared:                  0.147
# Method:                 Least Squares   F-statistic:                     29.11
# Date:                Wed, 05 Dec 2018   Prob (F-statistic):           2.37e-07
# Time:                        16:09:21   Log-Likelihood:                 147.43
# No. Observations:                 165   AIC:                            -290.9
# Df Residuals:                     163   BIC:                            -284.7
# Df Model:                           1
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Constant       0.1118      0.020      5.636      0.000       0.073       0.151
# idif          -0.0303      0.006     -5.396      0.000      -0.041      -0.019
# ==============================================================================
# Omnibus:                        2.382   Durbin-Watson:                   0.266
# Prob(Omnibus):                  0.304   Jarque-Bera (JB):                2.440
# Skew:                           0.267   Prob(JB):                        0.295
# Kurtosis:                       2.738   Cond. No.                         12.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# """

# %%
model4 = sm.OLS(dataset1["UIPdev"],dataset1[["Constant","monetaryShock","intervention"]])
result4 = model4.fit(cov_type="HAC",cov_kwds={"maxlags":1})
result4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 UIPdev   R-squared:                       0.165
# Model:                            OLS   Adj. R-squared:                  0.154
# Method:                 Least Squares   F-statistic:                     16.16
# Date:                Wed, 05 Dec 2018   Prob (F-statistic):           4.18e-07
# Time:                        16:09:21   Log-Likelihood:                -269.19
# No. Observations:                 159   AIC:                             544.4
# Df Residuals:                     156   BIC:                             553.6
# Df Model:                           2
# Covariance Type:                  HAC
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Constant         -3.7909      0.146    -25.947      0.000      -4.077      -3.505
# monetaryShock    -3.0544      0.551     -5.546      0.000      -4.134      -1.975
# intervention      5.1912      2.026      2.562      0.010       1.220       9.163
# ==============================================================================
# Omnibus:                        8.995   Durbin-Watson:                   0.206
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):                7.099
# Skew:                           0.415   Prob(JB):                       0.0287
# Kurtosis:                       2.381   Cond. No.                         17.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# """

# %%
model5 = sm.OLS(dataset1["UIPdev"],dataset1[["Constant","monetaryShock","intervention"]])
result5 = model5.fit(cov_type="HAC",cov_kwds={"maxlags":1})
if latex == True:
    for line in result5.summary().tables:
        print(line.as_latex_tabular())
print(result5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 UIPdev   R-squared:                       0.165
# Model:                            OLS   Adj. R-squared:                  0.154
# Method:                 Least Squares   F-statistic:                     16.16
# Date:                Wed, 05 Dec 2018   Prob (F-statistic):           4.18e-07
# Time:                        16:09:21   Log-Likelihood:                -269.19
# No. Observations:                 159   AIC:                             544.4
# Df Residuals:                     156   BIC:                             553.6
# Df Model:                           2
# Covariance Type:                  HAC
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Constant         -3.7909      0.146    -25.947      0.000      -4.077      -3.505
# monetaryShock    -3.0544      0.551     -5.546      0.000      -4.134      -1.975
# intervention      5.1912      2.026      2.562      0.010       1.220       9.163
# ==============================================================================
# Omnibus:                        8.995   Durbin-Watson:                   0.206
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):                7.099
# Skew:                           0.415   Prob(JB):                       0.0287
# Kurtosis:                       2.381   Cond. No.                         17.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction

# %%
dataset1.to_stata("dataset1.dta")

# %%
"""
dataset["monetaryShock_lag1"] = dataset["monetaryShock"].shift()
dataset["monetaryShock_lag2"] = dataset["monetaryShock_lag1"].shift()
dataset["monetaryShock_lag3"] = dataset["monetaryShock_lag2"].shift()
dataset["monetaryShock_lag4"] = dataset["monetaryShock_lag3"].shift()
dataset["monetaryShock_lag5"] = dataset["monetaryShock_lag4"].shift()

dataset = dataset.dropna()
dynamicModel = sm.OLS(dataset["UIPdev"],dataset[["Constant","monetaryShock","monetaryShock_lag1","monetaryShock_lag2",
                                                "monetaryShock_lag3","monetaryShock_lag4","monetaryShock_lag5"]])
dynamicResult = dynamicModel.fit(cov_type="HAC",cov_kwds={"maxlags":1})
dynamicResult.summary()
"""
# Out:
# '\ndataset["monetaryShock_lag1"] = dataset["monetaryShock"].shift()\ndataset["monetaryShock_lag2"] = dataset["monetaryShock_lag1"].shift()\ndataset["monetaryShock_lag3"] = dataset["monetaryShock_lag2"].shift()\ndataset["monetaryShock_lag4"] = dataset["monetaryShock_lag3"].shift()\ndataset["monetaryShock_lag5"] = dataset["monetaryShock_lag4"].shift()\n\ndataset = dataset.dropna()\ndynamicModel = sm.OLS(dataset["UIPdev"],dataset[["Constant","monetaryShock","monetaryShock_lag1","monetaryShock_lag2",\n                                                "monetaryShock_lag3","monetaryShock_lag4","monetaryShock_lag5"]])\ndynamicResult = dynamicModel.fit(cov_type="HAC",cov_kwds={"maxlags":1})\ndynamicResult.summary()\n'

# %%
#plt.plot(np.arange(6),dynamicResult.params.iloc[1:].values)
#plt.grid(True)

# %%
import statsmodels.tsa.api as ts
Vardata = dataset.copy()
Vardata["monetaryShock"] = Vardata["monetaryShock"]
Vardata = Vardata.dropna()
Varmodel = ts.VAR(Vardata[["UIPdev","monetaryShock"]])
Varresult = Varmodel.fit(6)
print(Varresult.summary())
irf = Varresult.irf(6)
irf.plot(impulse="monetaryShock")
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 05, Dec, 2018
# Time:                     16:09:21
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -6.56156
# Nobs:                     160.000    HQIC:                  -6.81269
# Log likelihood:           126.691    FPE:                0.000926627
# AIC:                     -6.98439    Det(Omega_mle):     0.000811246
# --------------------------------------------------------------------
# Results for equation UIPdev
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                   -0.095147         0.055150           -1.725           0.084
# L1.UIPdev                0.750991         0.086924            8.640           0.000
# L1.monetaryShock        -0.840800         0.153997           -5.460           0.000
# L2.UIPdev                0.128740         0.106412            1.210           0.226
# L2.monetaryShock        -0.170776         0.168338           -1.014           0.310
# L3.UIPdev                0.176616         0.106655            1.656           0.098
# L3.monetaryShock         0.111025         0.165174            0.672           0.501
# L4.UIPdev               -0.061388         0.105018           -0.585           0.559
# L4.monetaryShock         0.097303         0.160824            0.605           0.545
# L5.UIPdev               -0.020210         0.085381           -0.237           0.813
# L5.monetaryShock        -0.074492         0.144699           -0.515           0.607
# ===================================================================================
#
# Results for equation monetaryShock
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                    0.027898         0.030949            0.901           0.367
# L1.UIPdev               -0.079985         0.048780           -1.640           0.101
# L1.monetaryShock         0.307509         0.086419            3.558           0.000
# L2.UIPdev               -0.014334         0.059716           -0.240           0.810
# L2.monetaryShock         0.135116         0.094467            1.430           0.153
# L3.UIPdev                0.006630         0.059852            0.111           0.912
# L3.monetaryShock         0.036227         0.092692            0.391           0.696
# L4.UIPdev                0.115861         0.058933            1.966           0.049
# L4.monetaryShock         0.032005         0.090250            0.355           0.723
# L5.UIPdev               -0.018703         0.047914           -0.390           0.696
# L5.monetaryShock         0.102608         0.081202            1.264           0.206
# ===================================================================================
#
# Correlation matrix of residuals
#                    UIPdev  monetaryShock
# UIPdev           1.000000      -0.332782
# monetaryShock   -0.332782       1.000000
# c:\users\49048\appdata\local\programs\python\python37\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
#Adding controll for The other country's inflation and unemployment.
infUK = pd.Series(infl_raw["JP CPI: NATIONAL MEASURE SADJ"].pct_change().values,index=infl_raw.iloc[:,0].values)
dataset["inflationAU"]= infUK[start:end]
unemp_raw = pd.read_excel("data/unemployment_rate.xlsx")
UKunemp = pd.Series(unemp_raw["AU UNEMPLOYMENT RATE (LABOUR FORCE SURVEY ESTIMATE) SADJ"].values,index=unemp_raw.iloc[:,0].values)
dataset["unempAU"] = UKunemp
dataset["inflationUS"]  = infl
# Out:
#               UIPdev  Constant  monetaryShock  intervention   exchgrt  \
# 1994-04-15 -1.930139         1       0.444760      0.084318 -4.637879
# 1994-05-15 -2.816977         1       0.239387      0.031970 -4.649235
# 1994-06-15 -2.510159         1       0.010754      0.011577 -4.643573
# 1994-07-15 -2.894512         1       0.211835      0.065181 -4.572698
# 1994-08-15 -2.981812         1       0.262955      0.044165 -4.605070
# 1994-09-15 -2.989172         1       0.044624      0.048605 -4.594968
# 1994-10-15 -3.232348         1       0.545769     -0.031321 -4.604019
# 1994-11-15 -3.769793         1       0.178765      0.025218 -4.579852
# 1994-12-15 -4.484140         1       0.098644     -0.008951 -4.603919
# 1995-01-15 -4.417898         1       0.410690      0.008445 -4.595574
# 1995-02-15 -4.316799         1       0.093502     -0.014510 -4.594362
# 1995-03-15 -4.400291         1       0.109366      0.090426 -4.513493
# 1995-04-15 -4.852843         1      -0.000462      0.163806 -4.431769
# 1995-05-15 -4.747277         1       0.035410      0.131850 -4.462511
# 1995-06-15 -4.850714         1      -0.103940      0.081011 -4.432482
# 1995-07-15 -4.951752         1      -0.057496     -0.040441 -4.472210
# 1995-08-15 -5.185057         1       0.101030     -0.078120 -4.540632
# 1995-09-15 -5.121778         1       0.004289     -0.180408 -4.612890
# 1995-10-15 -5.385117         1       0.084693     -0.135407 -4.607617
# 1995-11-15 -5.242273         1      -0.149232     -0.071514 -4.612146
# 1995-12-15 -5.036835         1       0.007179     -0.010169 -4.623059
# 1996-01-15 -4.519385         1      -0.295106     -0.047105 -4.654722
# 1996-02-15 -4.115369         1       0.127318     -0.056515 -4.668661
# 1996-03-15 -4.971087         1      -0.049985     -0.037025 -4.660084
# 1996-04-15 -4.588033         1       0.051642     -0.033640 -4.688362
# 1996-05-15 -4.806983         1       0.064466      0.011373 -4.657288
# 1996-06-15 -4.902476         1       0.160752     -0.035612 -4.695696
# 1996-07-15 -4.824205         1      -0.141885     -0.018101 -4.706462
# 1996-08-15 -4.797471         1       0.114630     -0.020900 -4.678188
# 1996-09-15 -5.208962         1      -0.032305     -0.004602 -4.700299
# ...              ...       ...            ...           ...       ...
# 2005-07-15 -3.572940         1       0.211070     -0.024319 -4.708854
# 2005-08-15 -3.890340         1       0.093632     -0.025727 -4.695514
# 2005-09-15 -3.770343         1       0.137819     -0.012553 -4.698888
# 2005-10-15 -4.053509         1       0.222257     -0.030453 -4.739308
# 2005-11-15 -4.266335         1       0.174083     -0.074874 -4.770388
# 2005-12-15 -4.196244         1       0.126213     -0.088479 -4.787367
# 2006-01-15 -4.343693         1       0.180849      0.002013 -4.737294
# 2006-02-15 -4.562747         1       0.101560      0.002589 -4.767799
# 2006-03-15 -4.428436         1       0.199161      0.007361 -4.780005
# 2006-04-15 -4.564136         1       0.138864     -0.036648 -4.773942
# 2006-05-15 -4.593577         1       0.049784      0.063010 -4.704789
# 2006-06-15 -4.696903         1       0.248308      0.040523 -4.739483
# 2006-07-15 -4.622824         1       0.005914      0.024022 -4.749920
# 2006-08-15 -4.479883         1      -0.004898     -0.049189 -4.753978
# 2006-09-15 -4.434389         1       0.025429     -0.029124 -4.768606
# 2006-10-15 -4.397358         1       0.025568     -0.033522 -4.783442
# 2006-11-15 -4.273684         1       0.003508     -0.012120 -4.766098
# 2006-12-15 -4.202609         1      -0.003238      0.005621 -4.762986
# 2007-01-15 -4.196123         1       0.015129     -0.006921 -4.790363
# 2007-02-15 -4.209278         1      -0.013171     -0.036324 -4.802421
# 2007-03-15 -4.027125         1      -0.028825     -0.003580 -4.766566
# 2007-04-15 -4.042456         1      -0.021111      0.011659 -4.778703
# 2007-05-15 -3.877702         1      -0.024201      0.014055 -4.788366
# 2007-06-15 -3.825259         1      -0.008634     -0.035445 -4.802011
# 2007-07-15 -3.891120         1      -0.255731     -0.029040 -4.807744
# 2007-08-15 -3.294117         1      -0.098162      0.019505 -4.768861
# 2007-09-15 -2.977307         1      -0.215465      0.064016 -4.737995
# 2007-10-15 -3.056967         1      -0.299781      0.041944 -4.765800
# 2007-11-15 -2.315233         1      -0.305369      0.074079 -4.694782
# 2007-12-15 -1.974050         1      -0.345989      0.017400 -4.720595
#
#                 sdif      idif
# 1994-04-15  0.206111  2.136250
# 1994-05-15  0.186723  3.003700
# 1994-06-15  0.211091  2.721250
# 1994-07-15  0.100488  2.995000
# 1994-08-15  0.064438  3.046250
# 1994-09-15 -0.017922  2.971250
# 1994-10-15 -0.003598  3.228750
# 1994-11-15 -0.032293  3.737500
# 1994-12-15 -0.019140  4.465000
# 1995-01-15 -0.059148  4.358750
# 1995-02-15 -0.074299  4.242500
# 1995-03-15 -0.146591  4.253700
# 1995-04-15 -0.256593  4.596250
# 1995-05-15 -0.194777  4.552500
# 1995-06-15 -0.263214  4.587500
# 1995-07-15 -0.234252  4.717500
# 1995-08-15 -0.137557  5.047500
# 1995-09-15 -0.087408  5.034370
# 1995-10-15 -0.107617  5.277500
# 1995-11-15 -0.100398  5.141875
# 1995-12-15 -0.107465  4.929370
# 1996-01-15 -0.098135  4.421250
# 1996-02-15 -0.150369  3.965000
# 1996-03-15 -0.149087  4.822000
# 1996-04-15 -0.149031  4.439002
# 1996-05-15 -0.117583  4.689400
# 1996-06-15 -0.039976  4.862500
# 1996-07-15 -0.026705  4.797500
# 1996-08-15 -0.074971  4.722500
# 1996-09-15 -0.093962  5.115000
# ...              ...       ...
# 2005-07-15 -0.041065  3.531875
# 2005-08-15 -0.058465  3.831875
# 2005-09-15 -0.069718  3.700625
# 2005-10-15 -0.044134  4.009375
# 2005-11-15  0.004290  4.270625
# 2005-12-15  0.024381  4.220625
# 2006-01-15 -0.053068  4.290625
# 2006-02-15 -0.034622  4.528125
# 2006-03-15  0.013439  4.441875
# 2006-04-15 -0.004761  4.559375
# 2006-05-15 -0.083577  4.510000
# 2006-06-15 -0.062528  4.634375
# 2006-07-15 -0.057824  4.565000
# 2006-08-15 -0.014883  4.465000
# 2006-09-15  0.030611  4.465000
# 2006-10-15  0.017642  4.415000
# 2006-11-15  0.071316  4.345000
# 2006-12-15  0.042391  4.245000
# 2007-01-15  0.098877  4.295000
# 2007-02-15  0.125722  4.335000
# 2007-03-15  0.137875  4.165000
# 2007-04-15  0.162544  4.205000
# 2007-05-15  0.147298  4.025000
# 2007-06-15  0.119741  3.945000
# 2007-07-15  0.143880  4.035000
# 2007-08-15  0.070884  3.365001
# 2007-09-15  0.062693  3.040000
# 2007-10-15  0.163033  3.220000
# 2007-11-15  0.134767  2.450000
# 2007-12-15  0.205951  2.180001
#
# [165 rows x 7 columns]

# %%
infl_raw["JP CPI: NATIONAL MEASURE SADJ"]
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
#        ...
# 796     99.7
# 797     99.8
# 798     99.8
# 799     99.7
# 800     99.7
# 801    100.2
# 802    100.3
# 803    100.1
# 804    100.2
# 805    100.1
# 806    100.1
# 807    100.1
# 808    100.2
# 809    100.2
# 810    100.2
# 811    100.4
# 812    100.4
# 813    100.4
# 814    100.9
# 815    101.1
# 816    101.5
# 817    101.6
# 818    101.2
# 819    100.8
# 820    100.8
# 821    100.9
# 822    101.2
# 823    101.7
# 824    101.6
# 825      NaN
# Name: JP CPI: NATIONAL MEASURE SADJ, Length: 826, dtype: float64
